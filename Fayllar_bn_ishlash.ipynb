# %% [markdown]
# <a href="https://colab.research.google.com/github/Nur9702/15-dars/blob/main/Fayllar_bn_ishlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/Nur9702/python-lessons/refs/heads/main/00-jupyter/11-if-elif-else.ipynb
# Out:
# --2025-01-21 06:51:19--  https://raw.githubusercontent.com/Nur9702/python-lessons/refs/heads/main/00-jupyter/11-if-elif-else.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27639 (27K) [text/plain]
# Saving to: ‘11-if-elif-else.ipynb’
#
# 11-if-elif-else.ipy 100%[===================>]  26.99K  --.-KB/s    in 0.002s
#
# 2025-01-21 06:51:19 (10.7 MB/s) - ‘11-if-elif-else.ipynb’ saved [27639/27639]

# %%
! git clone https://github.com/Nur9702/python-lessons
# Out:
# Cloning into 'python-lessons'...
# remote: Enumerating objects: 333, done.
# remote: Counting objects: 100% (333/333), done.
# remote: Compressing objects: 100% (297/297), done.
# remote: Total 333 (delta 20), reused 324 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (333/333), 14.00 MiB | 31.04 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
import json
df = pd.read_csv("sample_data/california_housing_train.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df = pd.read_csv("sample_data/california_housing_train.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
pd.read_excel("eshkak_eshis.xlsx", index_col=2)
# Out:
#                                                                                Unnamed: 0  \
# NaN                                     Ўзбекистон "ROWING & CANOE" федерациясининг Ре...
# Мураббий, спортчи ва тиббиёт ходимлари                                                  №
# Мураббий                                                                                1
# Спортчи                                                                               NaN
# Тиббиёт ходимлари                                                                     NaN
# Мураббий                                                                                2
# Спортчи                                                                               NaN
# Тиббиёт ходимлари                                                                     NaN
# Мураббий                                                                                3
# ...

# %%
pd.read_csv("sample_data/california_housing_test.csv", nrows=15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# 5     -119.56     36.51                37.0       1018.0           213.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# ...

# %%
df = pd.read_excel("eshkak_eshis.xlsx", index_col=2)
df
# Out:
#                                                                                Unnamed: 0  \
# NaN                                     Ўзбекистон "ROWING & CANOE" федерациясининг Ре...
# Мураббий, спортчи ва тиббиёт ходимлари                                                  №
# Мураббий                                                                                1
# Спортчи                                                                               NaN
# Тиббиёт ходимлари                                                                     NaN
# Мураббий                                                                                2
# Спортчи                                                                               NaN
# Тиббиёт ходимлари                                                                     NaN
# Мураббий                                                                                3
# ...

# %%
df.to_csv("newuzb.csv")

# %%
pd.read_csv("newuzb.csv")
# Out:
#                               Unnamed: 0.1  \
# 0                                      NaN
# 1   Мураббий, спортчи ва тиббиёт ходимлари
# 2                                 Мураббий
# 3                                  Спортчи
# 4                        Тиббиёт ходимлари
# 5                                 Мураббий
# 6                                  Спортчи
# 7                        Тиббиёт ходимлари
# 8                                 Мураббий
# 9                                  Спортчи
# 10                       Тиббиёт ходимлари
#
#                                            Unnamed: 0  \
# 0   Ўзбекистон "ROWING & CANOE" федерациясининг Ре...
# 1                                                   №
# 2                                                   1
# 3                                                 NaN
# 4                                                 NaN
# 5                                                   2
# 6                                                 NaN
# ...

# %%
# Out:
#                                                                                Unnamed: 0  \
# NaN                                     Ўзбекистон "ROWING & CANOE" федерациясининг Ре...
# Мураббий, спортчи ва тиббиёт ходимлари                                                  №
# Мураббий                                                                                1
# Спортчи                                                                               NaN
# Тиббиёт ходимлари                                                                     NaN
# Мураббий                                                                                2
# Спортчи                                                                               NaN
# Тиббиёт ходимлари                                                                     NaN
# Мураббий                                                                                3
# ...

# %%
import requests
url =
